# %% [markdown]
# Какие блюда сложнее всего готовить, какие — легче всего? Будем считать, что чем больше ингредиентов — тем сложнее готовить

# %% [markdown]
# Импорт pandas и matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Группируем по рецептам, считаем кол-во ингредиентов, сортируем по возрастанию

# %%
recipes = df.groupby("name").agg({"ingredient": "count"}).sort_values(by="ingredient")
# Out:
#                                                     ingredient
# name
# klassicheskie-jajca-v-meshochek-15178                        6
# jaichnica-s-gribami-25451                                    6
# jajca-vkrutuju-15180                                         6
# jajca-vsmjatku-bez-kipjachenija-15176                        6
# jajca-vsmjatku-30908                                         6
# ...                                                        ...
# poke-s-lososem-i-sousom-nikkey-125144                      200
# olenina-s-seldereem-i-lakrichnim-sousom-47445              200
# telyatina-s-brusnichnym-sousom-v-rzhanom-karava...         204
# varenoe-mjaso-s-kislo-ostrim-sousom-20076                  206
# nozhka-krolika-34927                                       220
#
# [22824 rows x 1 columns]

# %% [markdown]
# Наиболее легкие в приготовлении:

# %%
recipes.head(10)
# Out:
#                                                 ingredient
# name
# klassicheskie-jajca-v-meshochek-15178                    6
# jaichnica-s-gribami-25451                                6
# jajca-vkrutuju-15180                                     6
# jajca-vsmjatku-bez-kipjachenija-15176                    6
# jajca-vsmjatku-30908                                     6
# omlet-po-japonski-39151                                  6
# jajca-zapechennie-v-duhovke-s-kolbaskami-34674           6
# jajca-pashot-v-bulochke-44592                            6
# jaichnica-s-seldju-15188                                 7
# jaicnica-s-kuricej-v-soevom-souse-47506                  7

# %% [markdown]
# Все наиболее лёгкие для приготовления блюда — вариации яичниц и омлетов

# %%
recipes.head(10).plot.bar(
    title="Наиболее легкие в приготовлении блюда",
    xlabel="Рецепт",
    ylabel="Кол-во ингредиентов"
)
# Out:
# <AxesSubplot:title={'center':'Наиболее легкие в приготовлении блюда'}, xlabel='Рецепт', ylabel='Кол-во ингредиентов'>

# %% [markdown]
# Наименее легкие в приготовлении:

# %%
recipes.tail(10)
# Out:
#                                                     ingredient
# name
# cesarka-s-prjanim-pilavom-iz-kinoa-40258                   188
# tayskiy-salat-s-kunzhutno-chesnochnoy-zapravkoy...         188
# minestrone-27683                                           188
# glazirovannyy-cyplenok-s-bulgurom-v-travah-i-s-...         192
# fazan-s-krasnoj-kapustoj-i-dikim-risom-40284               194
# poke-s-lososem-i-sousom-nikkey-125144                      200
# olenina-s-seldereem-i-lakrichnim-sousom-47445              200
# telyatina-s-brusnichnym-sousom-v-rzhanom-karava...         204
# varenoe-mjaso-s-kislo-ostrim-sousom-20076                  206
# nozhka-krolika-34927                                       220

# %%
recipes.tail(10).plot.bar(
    title="Наименее легкие в приготовлении блюда",
    xlabel="Рецепт",
    ylabel="Кол-во ингредиентов"
)
# Out:
# <AxesSubplot:title={'center':'Наименее легкие в приготовлении блюда'}, xlabel='Рецепт', ylabel='Кол-во ингредиентов'>
